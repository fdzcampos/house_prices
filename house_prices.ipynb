# %% [markdown]
# <a href="https://colab.research.google.com/github/fdzcampos/house_prices/blob/main/house_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # House prices

# %%
from google.colab import files

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LinearRegression

from sklearn import metrics

# %% [markdown]
# ## Data

# %%
files.upload()
# Out:
#      <input type="file" id="files-a2264b9f-5c57-4240-a5f8-74fcc755ceb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2264b9f-5c57-4240-a5f8-74fcc755ceb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train.csv to train.csv
# ...

# %%
train = pd.read_csv('train.csv', index_col= 0)
train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
test = pd.read_csv('test.csv', index_col= 0)
test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# Id                                      ...
# 1461          20       RH         80.0  ...    2010       WD        Normal
# 1462          20       RL         81.0  ...    2010       WD        Normal
# 1463          60       RL         74.0  ...    2010       WD        Normal
# 1464          60       RL         78.0  ...    2010       WD        Normal
# 1465         120       RL         43.0  ...    2010       WD        Normal
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Feature Selection

# %%
plt.figure(figsize=(25, 15))
sns.heatmap(train.corr().abs(), annot= True)
plt.show()

# %% [markdown]
# ### Correlation Manual Selection

# %%
# nos quedamos solo con las correlaciones que afectan al precio que queremos predecir
tcorr = train.corr().abs()
tcorr_saleprice = tcorr.loc[:, ['SalePrice']]

# %%
tcorr_saleprice.sort_values('SalePrice', ascending= False)
# Out:
#                SalePrice
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# BsmtFullBath    0.227122
# BsmtUnfSF       0.214479
# BedroomAbvGr    0.168213
# KitchenAbvGr    0.135907
# EnclosedPorch   0.128578
# ScreenPorch     0.111447
# PoolArea        0.092404
# MSSubClass      0.084284
# OverallCond     0.077856
# MoSold          0.046432
# 3SsnPorch       0.044584
# YrSold          0.028923
# LowQualFinSF    0.025606
# MiscVal         0.021190
# BsmtHalfBath    0.016844
# ...

# %%
feat = tcorr_saleprice[tcorr_saleprice['SalePrice'] > 0.5].sort_values('SalePrice', ascending= False)
feat = list(feat.index)
train_selec = train.loc[:, feat]

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train_selec.corr().abs(), annot= True)
plt.show()

# %%
selected_features = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF', 'FullBath', 'YearBuilt', 'YearRemodAdd']
train_selec = train_selec.loc[:, selected_features]

# %%
sns.pairplot(train_selec)

# %% [markdown]
# ### SelectKBest

# %%
train_labels = train.loc[:, ['SalePrice']]
train_feat = train.iloc[:, :-2]
train_feat = train_feat.loc[:, train_feat.dtypes.values != 'object'  ]

# %%
train_feat.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           2003       196.0         706           0        150          856
# 2           1976         0.0         978           0        284         1262
# 3           2002       162.0         486           0        434          920
# 4           1970         0.0         216           0        540          756
# 5           2000       350.0         655           0        490         1145
#
# ...

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values= np.nan, strategy= 'mean')
imp.fit_transform(train_feat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-180-34a54915ba24> in <module>()
#       1 from sklearn.impute import SimpleImputer
#       2 imp = SimpleImputer(missing_values= np.nan, strategy= 'mean')
# ----> 3 imp.fit_transform(train_feat).toarray()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'toarray'

# %%
X_new = SelectKBest(chi2, k=8).fit_transform(train_feat, train_labels)
X_new
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-04960108b214> in <module>()
# ----> 1 X_new = SelectKBest(chi2, k=8).fit_transform(train_feat, train_labels)
#       2 X_new
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     848         else:
#     849             # fit method of arity 2 (supervised transformation)
# --> 850             return self.fit(X, y, **fit_params).transform(X)
#     851
#     852
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     396         """
#     397         X, y = self._validate_data(
# --> 398             X, y, accept_sparse=["csr", "csc"], multi_output=True
#     399         )
#     400
#
# ...

# %% [markdown]
# ## Modelo

# %%
train_labels = train_selec.loc[:, ['SalePrice']]
train_feat = train_selec.iloc[:, 1:]

# %%
x_train, x_test, y_train, y_test = train_test_split(train_feat, train_labels)

# %%
lmodel = LinearRegression()
lmodel.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lmodel.intercept_, lmodel.coef_
# Out:
# (array([-1235345.39118857]),
#  array([[17154.84630112,    61.90544399,    45.89461964,    39.54431622,
#          -8831.63015409,   303.50859964,   287.43532125]]))

# %%
preds = lmodel.predict(x_test)

# %%
print('MAE', metrics.mean_absolute_error(y_test, preds))
print('MSE', metrics.mean_squared_error(y_test, preds))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test, preds)))
print('R2', metrics.r2_score(y_test, preds))
# Out:
# MAE 23854.979289945306
# MSE 2019613496.6070676
# RMSE 44940.11010897801
# R2 0.646438885957646

# %% [markdown]
# ## Entrega

# %%
test_selec = test.loc[:, selected_features[1: ]]
test_selec
# Out:
#       OverallQual  GrLivArea  GarageArea  TotalBsmtSF  FullBath  YearBuilt  \
# Id
# 1461            5        896       730.0        882.0         1       1961
# 1462            6       1329       312.0       1329.0         1       1958
# 1463            5       1629       482.0        928.0         2       1997
# 1464            6       1604       470.0        926.0         2       1998
# 1465            8       1280       506.0       1280.0         2       1992
# ...           ...        ...         ...          ...       ...        ...
# 2915            4       1092         0.0        546.0         1       1970
# 2916            4       1092       286.0        546.0         1       1970
# 2917            5       1224       576.0       1224.0         1       1960
# 2918            5        970         0.0        912.0         1       1992
# 2919            7       2000       650.0        996.0         2       1993
#
#       YearRemodAdd
# Id
# 1461          1961
# ...

# %%
preds = lmodel.predict(test_selec)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-06af6c7e5055> in <module>()
# ----> 1 preds = lmodel.predict(test_selec)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
#     344
# --> 345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#
# ...

# %%
test_selec.isna().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# GarageArea      1
# TotalBsmtSF     1
# FullBath        0
# YearBuilt       0
# YearRemodAdd    0
# dtype: int64

# %%
test_selec['GarageArea'].fillna(0, inplace= True)
test_selec['TotalBsmtSF'].fillna(np.mean(test_selec['TotalBsmtSF']), inplace= True)
test_selec.isna().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# GarageArea      0
# TotalBsmtSF     0
# FullBath        0
# YearBuilt       0
# YearRemodAdd    0
# dtype: int64

# %%
preds = lmodel.predict(test_selec)

# %%
dfpreds.index
# Out:
# RangeIndex(start=0, stop=1459, step=1)

# %%
df = pd.DataFrame(preds)
df.insert(0, 'Id', test.index)
df
# Out:
#         Id              0
# 0     1461  124286.676095
# 1     1462  164966.106217
# 2     1463  172830.325730
# 3     1464  188111.220463
# 4     1465  214468.779937
# ...    ...            ...
# 1454  2915   77793.829514
# 1455  2916   90919.690732
# 1456  2917  160804.774088
# 1457  2918  114870.197644
# 1458  2919  238142.471970
#
# [1459 rows x 2 columns]

# %%
df.columns = ['Id', 'SalePrice']
df
# Out:
#         Id      SalePrice
# 0     1461  124286.676095
# 1     1462  164966.106217
# 2     1463  172830.325730
# 3     1464  188111.220463
# 4     1465  214468.779937
# ...    ...            ...
# 1454  2915   77793.829514
# 1455  2916   90919.690732
# 1456  2917  160804.774088
# 1457  2918  114870.197644
# 1458  2919  238142.471970
#
# [1459 rows x 2 columns]

# %%
df.to_csv('lr_entrega.csv', index= False)
